# %% [markdown]
# <a href="https://colab.research.google.com/github/GantiAswini/FMML_LAB-MODULES/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 14:41:44--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json.1’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   204MB/s    in 0.3s
#
# 2024-03-31 14:41:45 (204 MB/s) - ‘arxiv-paper-data.json.1’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 11520  1605.05775v2  Tensor networks are efficient representations ...  stat
# 12341  1712.00673v1  Recent studies have revealed the vulnerability...    cs
# 34878   1203.6276v4  Variable selection is recognized as one of the...  stat
# 6444   1702.01992v1  This paper presents a novel model for multimod...  stat
# 9467    1108.0502v1  Fingertips detection has been used in many app...    cs
# ...             ...                                                ...   ...
# 27202  1702.07600v1  This work explores the feasibility of steering...    cs
# 31727   0804.4682v1  The use of computational intelligence techniqu...    cs
# 19663   1406.6973v1  Statements about entities occur everywhere, fr...    cs
# 7429   1712.08289v2  Many machine intelligence techniques are devel...    cs
# 39930  1707.09775v1  Deep convolutional neural networks follow roug...    cs
#
#                                                    title  year  \
# 11520  Supervised Learning with Quantum-Inspired Tens...  2016
# 12341  Towards Robust Neural Networks via Random Self...  2017
# 34878  A Multi-objective Exploratory Procedure for Re...  2012
# 6444       Gated Multimodal Units for Information Fusion  2017
# 9467   An Efficient Real Time Method of Fingertip Det...  2011
# ...                                                  ...   ...
# 27202  How hard is it to cross the room? -- Training ...  2017
# 31727  Introduction to Relational Networks for Classi...  2008
# 19663      Communicating and resolving entity references  2014
# 7429   Learning and Transferring IDs Representation i...  2017
# 39930  Capacity limitations of visual search in deep ...  2017
#
#                                                 keywords
# 11520  [efficient, representations, dimensional, succ...
# 12341  [vulnerability, adversarial, perturbation, imp...
# 34878  [selection, recognized, statistical, encounter...
# 6444   [multimodal, multimodal, architecture, interme...
# 9467   [fingertips, detection, applications, interact...
# ...                                                  ...
# 27202  [feasibility, navigation, framework, navigatio...
# 31727  [computational, intelligence, techniques, clas...
# 19663  [statements, everywhere, newspapers, structure...
# 7429   [intelligence, techniques, developed, essentia...
# 39930  [convolutional, architecture, biological, perf...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 11520    [efficient, representations, dimensional, succ...
# 12341    [vulnerability, adversarial, perturbation, imp...
# 34878    [selection, recognized, statistical, encounter...
# 6444     [multimodal, multimodal, architecture, interme...
# 9467     [fingertips, detection, applications, interact...
#                                ...
# 24916    [classifying, synthetic, addressed, innovative...
# 12094    [detection, management, difficult, increasing,...
# 34862    [algorithm, fluctuations, interpreted, fluctua...
# 29527    [automatic, recognition, streamlined, segmenti...
# 10989    [dimensional, significant, challenges, applica...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8771 words.
# Out of those 4627 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="88935d6c-53d4-4aae-a6b4-ea6851b4a34a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("88935d6c-53d4-4aae-a6b4-ea6851b4a34a")) {                    Plotly.newPlot(                        "88935d6c-53d4-4aae-a6b4-ea6851b4a34a",                        [{"x":["successful","structure","representations","classifying","generative","parameterize","classification","optimizing","mathematics","supervised","dimensional","additional","demonstrate","interpretation","efficient","algorithms","applications","integrate","technique","adversarial","important","distortion","algorithm","prediction","stochastic","predictive","procedure","capability","combining","techniques","perturbation","defensive","equivalent","tolerance","randomness","ensembles","performance","significantly","stabilize","vulnerability","outperforms","imperceptible","explanatory","minimization","importance","preferred","introduces","exploration","dominated","considers","selection","linearities","coefficients","difficulty","generalization","statistical","recognized","characterized","communities","evaluated","knowledge","published","exploratory","interdependencies","regressors","engineering","regression","eliminating","variables","encountered","objective","performed","intervention","abundance","intermediate","activation","modalities","different","multilabel","combination","including","influence","strategies","approaches","available","multimodal","architecture","outperformed","multiplicative","representation","information","histogram","irrelevant","detection","interaction","silhouette","generated","maximization","component","competing","optimality","likelihood","optimization","complexity","framework","probability","separation","dynamically","independent","estimation","computers","theoretical","underlying","separately","properties","functions","constraints","reasonable","simulated","directions","communications","processing","biomedical","therefore","measuring","implementations","parameter","clustering","sensitive","parametric","homogeneity","computationally","nonparametric","numerical","inhomogeneity","artificial","describes","sensitivity","departure","intensive","excellent","classifier","distribution","categorizing","effective","separated","recognition","discriminative","variation","advantages","extracted","essential","effectively","represented","directional","furthermore","perspective","distributions","permutation","viewpoint","feedforward","significant","improvements","evolution","efficiency","differential","symmetries","principle","introduce","covariance","evolutionary","direction","proximity","experimentally","illustrate","conceptually","investigations","literature","adaptation","convergence","technical","generalized","addressed","invariant","explanation","strengths","illumination","architectures","localization","experimental","structured","textureless","reduction","quantitative","comparison","conditions","extensive","correlation","weaknesses","dimensionality"],"y":[65,337,242,51,113,3,485,48,11,175,192,112,568,52,424,598,449,52,243,101,371,21,799,226,139,62,117,49,105,382,18,5,61,8,8,16,901,271,7,3,269,2,3,74,89,13,56,54,8,38,152,2,30,45,112,175,20,36,23,154,355,39,8,2,6,50,126,17,120,8,172,125,7,3,32,34,39,790,3,134,281,50,107,400,307,36,238,24,15,344,673,24,15,334,80,2,204,27,108,27,13,72,311,220,553,151,20,32,146,201,19,149,118,26,203,217,156,37,60,42,4,273,21,135,29,42,119,135,72,31,4,110,20,92,0,140,93,22,2,37,38,158,207,7,271,14,404,112,57,67,110,70,114,76,17,164,71,108,10,16,27,247,118,57,170,38,9,51,345,25,60,51,11,66,78,11,7,122,77,118,34,72,33,52,15,19,29,130,64,408,114,3,114,79,146,134,143,82,10,48],"type":"bar"},{"x":["successful","structure","representation ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4627,), (4627, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7933333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>Acquiring</span> <span style='background-color:rgba(0, 255, 0, 0.6952380952380952);'>Background</span> <span style='background-color:rgba(0, 255, 0, 0.4115308151093439);'>Knowledge</span> <span style=''>to</span> <span style=''>Improve</span> <span style=''>Moral</span> <span style=''>Value</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Prediction</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>address</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333326);'>detecting</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expressions</span> <span style=''>of</span> <span style=''>moral</span> <span style=''>values</span> <span style=''>in</span> <span style=''>tweets</span> <span style=''>using</span> <span style=''>content</span> <span style=''>analysis</span> <span style=''>This</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particularly</span> <span style='background-color:rgba(0, 255, 0, 0.44533333333333347);'>challenging</span> <span style=''>problem</span> <span style=''>because</span> <span style=''>moral</span> <span style=''>values</span> <span style=''>are</span> <span style=''>often</span> <span style=''>only</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implicitly</span> <span style=''>signaled</span> <span style=''>in</span> <span style=''>language</span> <span style=''>and</span> <span style=''>tweets</span> <span style=''>contain</span> <span style=''>little</span> <span style='background-color:rgba(0, 255, 0, 0.3090909090909091);'>contextual</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style=''>due</span> <span style=''>to</span> <span style=''>length</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraints</span> <span style=''>To</span> <span style=''>address</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>obstacles</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>approach</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.41428571428571437);'>automatically</span> <span style=''>acquire</span> <span style='background-color:rgba(0, 255, 0, 0.6952380952380952);'>background</span> <span style='background-color:rgba(0, 255, 0, 0.4115308151093439);'>knowledge</span> <span style=''>from</span> <span style=''>an</span> <span style=''>external</span> <span style='background-color:rgba(0, 255, 0, 0.4115308151093439);'>knowledge</span> <span style=''>base</span> <span style=''>to</span> <span style=''>enrich</span> <span style=''>input</span> <span style=''>texts</span> <span style=''>and</span> <span style=''>thus</span> <span style=''>improve</span> <span style=''>moral</span> <span style=''>value</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prediction</span> <span style=''>By</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>combining</span> <span style=''>basic</span> <span style=''>text</span> <span style=''>features</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.6952380952380952);'>background</span> <span style='background-color:rgba(0, 255, 0, 0.4115308151093439);'>knowledge</span> <span style=''>our</span> <span style=''>overall</span> <span style=''>context</span> <span style=''>aware</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>achieves</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>comparable</span> <span style=''>to</span> <span style=''>a</span> <span style=''>single</span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Nonparametric</span> <span style=''>Reduced</span> <span style=''>Rank</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Regression</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>an</span> <span style=''>approach</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multivariate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonparametric</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalizes</span> <span style=''>reduced</span> <span style=''>rank</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>for</span> <span style=''>linear</span> <span style=''>models</span> <span style=''>An</span> <span style=''>additive</span> <span style=''>model</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimated</span> <span style=''>for</span> <span style=''>each</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimension</span> <span style=''>of</span> <span style=''>a</span> <span style=''>q</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>response</span> <span style=''>with</span> <span style=''>a</span> <span style=''>shared</span> <span style=''>p</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictor</span> <span style=''>variable</span> <span style=''>To</span> <span style=''>control</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complexity</span> <span style=''>of</span> <span style=''>the</span> <span style=''>model</span> <span style=''>we</span> <span style=''>employ</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functional</span> <span style=''>form</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Ky</span> <span style=''>Fan</span> <span style=''>or</span> <span style=''>nuclear</span> <span style=''>norm</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>resulting</span> <span style=''>in</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>function</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimates</span> <span style=''>that</span> <span style=''>have</span> <span style=''>low</span> <span style=''>rank</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Backfitting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>are</span> <span style=''>derived</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>justified</span> <span style=''>using</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonparametric</span> <span style=''>form</span> <span style=''>of</span> <span style=''>the</span> <span style=''>nuclear</span> <span style=''>norm</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>subdifferential</span> <span style=''>Oracle</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inequalities</span> <span style=''>on</span> <span style=''>excess</span> <span style=''>risk</span> <span style=''>are</span> <span style=''>derived</span> <span style=''>that</span> <span style=''>exhibit</span> <span style=''>the</span> <span style=''>scaling</span> <span style=''>behavior</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>procedure</span> <span style=''>in</span> <span style=''>the</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>setting</span> <span style=''>The</span> <span style=''>methods</span> <span style=''>are</span> < ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Subset</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Selection</span> <span style=''>for</span> <span style=''>Gaussian</span> <span style=''>Markov</span> <span style=''>Random</span> <span style=''>Fields</span> <br/><br/><span style=''>Given</span> <span style=''>a</span> <span style=''>Gaussian</span> <span style=''>Markov</span> <span style=''>random</span> <span style=''>field</span> <span style=''>we</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selecting</span> <span style=''>a</span> <span style=''>subset</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.37500000000000006);'>variables</span> <span style=''>to</span> <span style=''>observe</span> <span style=''>which</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimizes</span> <span style=''>the</span> <span style=''>total</span> <span style=''>expected</span> <span style=''>squared</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prediction</span> <span style=''>error</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3076923076923077);'>unobserved</span> <span style='background-color:rgba(255, 0, 0, 0.37500000000000006);'>variables</span> <span style=''>We</span> <span style=''>first</span> <span style=''>show</span> <span style=''>that</span> <span style=''>finding</span> <span style=''>an</span> <span style=''>exact</span> <span style=''>solution</span> <span style=''>is</span> <span style=''>NP</span> <span style=''>hard</span> <span style=''>even</span> <span style=''>for</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>restricted</span> <span style=''>class</span> <span style=''>of</span> <span style=''>Gaussian</span> <span style=''>Markov</span> <span style=''>random</span> <span style=''>fields</span> <span style=''>called</span> <span style=''>Gaussian</span> <span style=''>free</span> <span style=''>fields</span> <span style=''>which</span> <span style=''>arise</span> <span style=''>in</span> <span style=''>semi</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>supervised</span> <span style=''>learning</span> <span style=''>and</span> <span style=''>computer</span> <span style=''>vision</span> <span style=''>We</span> <span style=''>then</span> <span style=''>give</span> <span style=''>a</span> <span style=''>simple</span> <span style=''>greedy</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>Gaussian</span> <span style=''>free</span> <span style=''>fields</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>arbitrary</span> <span style=''>graphs</span> <span style=''>Finally</span> <span style=''>we</span> <span style=''>give</span> <span style=''>a</span> <span style=''>message</span> <span style=''>passing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>general</span> <span style=''>Gaussian</span> <span style=''>Markov</span> <span style=''>random</span> <span style=''>fields</span> <span style=''>on</span> <span style=''>bounded</span> <span style=''>tree</span> <span style=''>width</span> <span style=''>graphs</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Bayesian</span> <span style=''>Model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Selection</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Stochastic</span> <span style=''>Block</span> <span style=''>Models</span> <br/><br/><span style=''>A</span> <span style=''>central</span> <span style=''>problem</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>analyzing</span> <span style=''>networks</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>partitioning</span> <span style=''>them</span> <span style=''>into</span> <span style=''>modules</span> <span style=''>or</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>communities</span> <span style=''>One</span> <span style=''>of</span> <span style=''>the</span> <span style=''>best</span> <span style=''>tools</span> <span style=''>for</span> <span style=''>this</span> <span style=''>is</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>block</span> <span style=''>model</span> <span style=''>which</span> <span style=''>clusters</span> <span style=''>vertices</span> <span style=''>into</span> <span style=''>blocks</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistically</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>homogeneous</span> <span style=''>pattern</span> <span style=''>of</span> <span style=''>links</span> <span style=''>Despite</span> <span style=''>its</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>flexibility</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>popularity</span> <span style=''>there</span> <span style=''>has</span> <span style=''>been</span> <span style=''>a</span> <span style=''>lack</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principled</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>criteria</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>block</span> <span style=''>model</span> <span style=''>Here</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>Bayesian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>for</span> <span style=''>choosing</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>blocks</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparing</span> <span style=''>it</span> <span style=''>to</span> <span style=''>the</span> <span style=''>more</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>elaborate</span> <span style=''>degree</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>corrected</span> <span style=''>block</span> <span style=''>models</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>ultimately</span> <span style=''>leading</span> <span style=''>to</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>universal</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>capable</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparing</span> <span style=''>multiple</span> <span style=''>modeling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>combinations</span> <span style=''>We</span> <span style=''>will</span> <span style=''>also</span> <span style='background-color:rgba(255, 0, 0, ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.08521303258145363)
# 	reasoning (0.05442176870748299)
# 	information (0.24095954171142142)
# 	segmentation (0.0694593626924454)
# 	knowledge (0.12710347296813462)
# 	experimental (0.1460794844253491)
# 	detection (0.11958467597565342)
# 	convolutional (0.13175796634443251)
# 	different (0.2828499820981024)
# 	recognition (0.14464733261725743)
#
# Some Statistics words are:
# 	convergence (0.12257100149476831)
# 	variables (0.13153961136023917)
# 	statistical (0.15146985550572994)
# 	estimation (0.16492277030393623)
# 	theoretical (0.14947683109118087)
# 	distribution (0.18086696562032886)
# 	inference (0.19083208769307425)
# 	algorithm (0.4020926756352765)
# 	dimensional (0.18834080717488788)
# 	regression (0.1898355754857997)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0763d1c9-0589-4086-8452-72c62d2212ed" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0763d1c9-0589-4086-8452-72c62d2212ed")) {                    Plotly.newPlot(                        "0763d1c9-0589-4086-8452-72c62d2212ed",                        [{"x":["successful","structure","representations","classifying","generative","parameterize","classification","optimizing","mathematics","supervised","dimensional","additional","demonstrate","interpretation","efficient","algorithms","applications","integrate","technique","adversarial","important","distortion","algorithm","prediction","stochastic","predictive","procedure","capability","combining","techniques","perturbation","defensive","equivalent","tolerance","randomness","ensembles","performance","significantly","stabilize","vulnerability","outperforms","imperceptible","explanatory","minimization","importance","preferred","introduces","exploration","dominated","considers","selection","linearities","coefficients","difficulty","generalization","statistical","recognized","characterized","communities","evaluated","knowledge","published","exploratory","interdependencies","regressors","engineering","regression","eliminating","variables","encountered","objective","performed","intervention","abundance","intermediate","activation","modalities","different","multilabel","combination","including","influence","strategies","approaches","available","multimodal","architecture","outperformed","multiplicative","representation","information","histogram","irrelevant","detection","interaction","silhouette","generated","maximization","component","competing","optimality","likelihood","optimization","complexity","framework","probability","separation","dynamically","independent","estimation","computers","theoretical","underlying","separately","properties","functions","constraints","reasonable","simulated","directions","communications","processing","biomedical","therefore","measuring","implementations","parameter","clustering","sensitive","parametric","homogeneity","computationally","nonparametric","numerical","inhomogeneity","artificial","describes","sensitivity","departure","intensive","excellent","classifier","distribution","categorizing","effective","separated","recognition","discriminative","variation","advantages","extracted","essential","effectively","represented","directional","furthermore","perspective","distributions","permutation","viewpoint","feedforward","significant","improvements","evolution","efficiency","differential","symmetries","principle","introduce","covariance","evolutionary","direction","proximity","experimentally","illustrate","conceptually","investigations","literature","adaptation","convergence","technical","generalized","addressed","invariant","explanation","strengths","illumination","architectures","localization","experimental","structured","textureless","reduction","quantitative","comparison","conditions","extensive","correlation","weaknesses","dimensionality","university","development","experimentation","population","collaborative","environment","participate","monolingual","demonstrated","magnitude","propagation","computational","guarantees","convolution","convolutional","conventional","mechanisms","computation","themselves","implementation","naturally","inference","frameworks","efficiently","resources","attention","exploiting","sophisticated","solutions","dedicated","challenging","variability","incidental","competition","difficulties","understanding","progresses","stimulate","diversity","challenge","intention","challenges","applicable","assignment","unsupervised","segmentation","successfully","experiments","relationships","occurrence","scenarios","assistive","relations ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	inhomogeneity
# 	sectional
# 	nomination
# 	proportionality
# 	thermodynamics
# 	andersson
# 	scoresearch
# 	compromises
# 	nonparanormal
# 	invaluable
# 	overconfident
# 	integrations
# 	reparametrization
# 	initialising
# 	subsamples
# 	degeneration
# 	syndromes
# 	nucleotide
# 	beginnings
# 	maturation
# Some words which never appear in Statistics papers:
# 	categorizing
# 	illumination
# 	textureless
# 	incidental
# 	stimulate
# 	assistive
# 	forgotten
# 	delimiting
# 	generations
# 	multiword
# 	agglutinative
# 	hyperplanes
# 	illuminations
# 	constancy
# 	confusing
# 	preparing
# 	morphologically
# 	chromaticity
# 	pinpointing
# 	collocated

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.071536075191203e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7558333333333334
